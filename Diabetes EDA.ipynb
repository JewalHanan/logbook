# %% [markdown]
# STEP 1: IMPORT LIBRARIES

# %%
#Importing dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# STEP 2:IMPORT DATASET

# %%
diabetics=pd.read_csv('diabetes-2.csv')
#splitting data into independent and dependent variable
X=diabetics.iloc[:,0:-1]
y=diabetics.iloc[:,-1]

# %% [markdown]
# STEP 3: EXPLORATORY DATA ANALYSIS

# %%
diabetics
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
diabetics.describe(include='all')
#helps us to understand how data has been spread across the table.
# count :- the number of NoN-empty rows in a feature.
# mean :- mean value of that feature.
# std :- Standard Deviation Value of that feature.
# min :- minimum value of that feature.
# max :- maximum value of that feature.
# 25%, 50%, and 75% are the percentile/quartile of each features.
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetics['Outcome'].value_counts()
#0 is non diabetic
#1 is diabetic
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
diabetics.head()#get familier with dataset, display the top 5 data records
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetics.shape #getting to know about rows and columns we're dealing with - 768 rows , 9 columns
# Out:
# (768, 9)

# %%
diabetics.dtypes #knowledge of data type helps for computation
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
diabetics.columns#learning about the columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#check for missing values, count them and print the sum for every column
print(diabetics.isna().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#checking for 0 values in 5 columns , Age & DiabetesPedigreeFunction 
#do not have have minimum 0 value so no need to replace , also no. of pregnancies as 0 is possible as observed in df.describe
print(diabetics[diabetics['BloodPressure']==0].shape[0])
print(diabetics[diabetics['Glucose']==0].shape[0])
print(diabetics[diabetics['SkinThickness']==0].shape[0])
print(diabetics[diabetics['Insulin']==0].shape[0])
print(diabetics[diabetics['BMI']==0].shape[0])
# Out:
# 35
# 5
# 227
# 374
# 11

# %%
#histogram for each  feature
diabetics.hist(figsize=(9, 9))
plt.show()

# %%
#replacing 0 values with median of that column
diabetics['Glucose']=diabetics['Glucose'].replace(0,diabetics['Glucose'].mean())#normal distribution
diabetics['BloodPressure']=diabetics['BloodPressure'].replace(0,diabetics['BloodPressure'].mean())#normal distribution
diabetics['SkinThickness']=diabetics['SkinThickness'].replace(0,diabetics['SkinThickness'].median())#skewed distribution
dfdiabetics['Insulin']=diabetics['Insulin'].replace(0,diabetics['Insulin'].median())#skewed distribution
diabetics['BMI']=diabetics['BMI'].replace(0,diabetics['BMI'].median())#skewed distribution
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 5>()
#       3 diabetics['BloodPressure']=diabetics['BloodPressure'].replace(0,diabetics['BloodPressure'].mean())#normal distribution
#       4 diabetics['SkinThickness']=diabetics['SkinThickness'].replace(0,diabetics['SkinThickness'].median())#skewed distribution
# ----> 5 dfdiabetics['Insulin']=diabetics['Insulin'].replace(0,diabetics['Insulin'].median())#skewed distribution
#       6 diabetics['BMI']=diabetics['BMI'].replace(0,diabetics['BMI'].median())
#
# NameError: name 'dfdiabetics' is not defined

# %% [markdown]
# STEP 4: DATA VISUALIZATION

# %%
#to see if the dataset is balanced or not
ax=sns.countplot(x ='Outcome', data = diabetics)
plt.show()

# %%
c=diabetics.corr()
c
#visualizing correlation matrix
sns.heatmap(c, annot=True);

# %%
diabetics_sel=X.drop(['BloodPressure','Insulin','DiabetesPedigreeFunction','SkinThickness','Pregnancies'],axis='columns')
diabetics_sel
# Out:
#      Glucose   BMI  Age
# 0        148  33.6   50
# 1         85  26.6   31
# 2        183  23.3   32
# 3         89  28.1   21
# 4        137  43.1   33
# ..       ...   ...  ...
# 763      101  32.9   63
# 764      122  36.8   27
# 765      121  26.2   30
# 766      126  30.1   47
# 767       93  30.4   23
#
# [768 rows x 3 columns]

# %%
#plotting boxplot to find outliers
plt.figure(figsize=(16,12))
sns.set_style(style='whitegrid')
plt.subplot(3,3,1)
sns.boxplot(x='Glucose',data=diabetics)
plt.subplot(3,3,2)
sns.boxplot(x='BloodPressure',data=diabetics)
plt.subplot(3,3,3)
sns.boxplot(x='Insulin',data=diabetics)
plt.subplot(3,3,4)
sns.boxplot(x='BMI',data=diabetics)
plt.subplot(3,3,5)
sns.boxplot(x='Age',data=diabetics)
plt.subplot(3,3,6)
sns.boxplot(x='SkinThickness',data=diabetics)
plt.subplot(3,3,7)
sns.boxplot(x='Pregnancies',data=diabetics)
plt.subplot(3,3,8)
sns.boxplot(x='DiabetesPedigreeFunction',data=diabetics)
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction'>

# %%
sns.pairplot(diabetics)

# %% [markdown]
# Splitting Dataset

# %%
#importing train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_sel, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# Classification Algorithms

# %%
#importing the algorith and fitting the dataset with the model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
Y_pred = model.predict(X_test)#Predict testing set
#Importing accuracy and confusion matrix
from sklearn.metrics import accuracy_score,confusion_matrix
a=accuracy_score(y_test,Y_pred)
a
# Out:
# 0.7857142857142857

# %%
cm = confusion_matrix(y_test,Y_pred)
print(cm)
# Out:
# [[89 10]
#  [23 32]]

# %%
#visualizing confusion matrix
sns.heatmap(cm, annot=True)
plt.show()

# %%
#calculating sensitivity and specificity from confusion matrix
sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity :', sensitivity )
specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity : ', specificity)
# Out:
# Sensitivity : 0.898989898989899
# Specificity :  0.5818181818181818

# %%
#importing fi_score, classification report
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
f1 = f1_score(y_test,Y_pred)
print("F1: ", f1)
# Out:
# F1:  0.6597938144329897

# %%
print(classification_report(y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84        99
#            1       0.76      0.58      0.66        55
#
#     accuracy                           0.79       154
#    macro avg       0.78      0.74      0.75       154
# weighted avg       0.78      0.79      0.78       154
